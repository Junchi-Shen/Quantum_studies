# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Using cached pennylane-0.43.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy in d:\python project\quantum_env\lib\site-packages (from pennylane) (1.16.3)
# Collecting networkx (from pennylane)
#   Downloading networkx-3.6-py3-none-any.whl.metadata (6.8 kB)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Using cached rustworkx-0.17.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting autograd (from pennylane)
#   Using cached autograd-1.8.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting appdirs (from pennylane)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.0 (from pennylane)
#   Using cached autoray-0.8.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting cachetools (from pennylane)
#   Using cached cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pennylane-lightning>=0.43 (from pennylane)
#   Using cached pennylane_lightning-0.43.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting requests (from pennylane)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tomlkit (from pennylane)
#   Using cached tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing_extensions in d:\python project\quantum_env\lib\site-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in d:\python project\quantum_env\lib\site-packages (from pennylane) (25.0)
# Collecting diastatic-malt (from pennylane)
#   Using cached diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in d:\python project\quantum_env\lib\site-packages (from pennylane) (2.3.5)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.43->pennylane)
#   Using cached scipy_openblas32-0.3.30.0.8-py3-none-win_amd64.whl.metadata (56 kB)
# Collecting astunparse (from diastatic-malt->pennylane)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting gast (from diastatic-malt->pennylane)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting termcolor (from diastatic-malt->pennylane)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests->pennylane)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->pennylane)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->pennylane)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->pennylane)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse->diastatic-malt->pennylane)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: six<2.0,>=1.6.1 in d:\python project\quantum_env\lib\site-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Using cached pennylane-0.43.1-py3-none-any.whl (5.3 MB)
# Using cached autoray-0.8.0-py3-none-any.whl (934 kB)
# Using cached pennylane_lightning-0.43.0-cp311-cp311-win_amd64.whl (5.4 MB)
# Using cached rustworkx-0.17.1-cp39-abi3-win_amd64.whl (2.1 MB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached autograd-1.8.0-py3-none-any.whl (51 kB)
# Using cached cachetools-6.2.2-py3-none-any.whl (11 kB)
# Using cached diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
# Downloading networkx-3.6-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------- ---------------------------- 0.6/2.1 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 22.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 18.7 MB/s eta 0:00:00
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-win_amd64.whl (106 kB)
#    ---------------------------------------- 0.0/107.0 kB ? eta -:--:--
#    ---------------------------------------- 107.0/107.0 kB 6.0 MB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
#    ---------------------------------------- 71.0/71.0 kB 4.1 MB/s eta 0:00:00
# Using cached scipy_openblas32-0.3.30.0.8-py3-none-win_amd64.whl (7.1 MB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: appdirs, wheel, urllib3, tomlkit, termcolor, scipy-openblas32, rustworkx, networkx, idna, gast, charset_normalizer, certifi, cachetools, autoray, autograd, requests, astunparse, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 astunparse-1.6.3 autograd-1.8.0 autoray-0.8.0 cachetools-6.2.2 certifi-2025.11.12 charset_normalizer-3.4.4 diastatic-malt-2.15.2 gast-0.6.0 idna-3.11 networkx-3.6 pennylane-0.43.1 pennylane-lightning-0.43.0 requests-2.32.5 rustworkx-0.17.1 scipy-openblas32-0.3.30.0.8 termcolor-3.2.0 tomlkit-0.13.3 urllib3-2.5.0 wheel-0.45.1
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import NesterovMomentumOptimizer

# %%
dev = qml.device("default.qubit")
dev
# Out:
# <default.qubit device at 0x1c981de4a90>

# %%
def layer(layer_weights):
    for wire in range(4):
        qml.Rot(*layer_weights[wire], wires=wire)

    for wires in ([0, 1], [1, 2], [2, 3], [3, 0]):
        qml.CNOT(wires)

# %%
def state_preparation(x):
    qml.BasisState(x, wires=[0, 1, 2, 3])

# %%
@qml.qnode(dev)
def circuit(weights, x):
    state_preparation(x)

    for layer_weights in weights:
        layer(layer_weights)

    return qml.expval(qml.PauliZ(0))

# %%
def variational_classifier(weights, bias, x):
    return circuit(weights, x) + bias
