# %% [markdown]
# # IBM quick start of Quantum circuit

# %% [markdown]
# # 1. Building the circuit

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
 
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()
 
sampler = StatevectorSampler()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

# plot the circuit
# from qiskit.visualization import circuit_drawer
# circuit_drawer(qc)

# plot the histogram
# Out:
# {'00': 514, '11': 510}
#         ┌───┐      ░ ┌─┐
#    q_0: ┤ H ├──■───░─┤M├───
#         └───┘┌─┴─┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├─░──╫─┤M├
#              └───┘ ░  ║ └╥┘
# meas: 2/══════════════╩══╩═
#                       0  1

# %% [markdown]
# ## Visualize it

# %%
import matplotlib.pyplot as plt

# import matplotlib.pyplot as plt
from qiskit.visualization import plot_histogram
 
counts = result[0].data.meas.get_counts()

plot_histogram(counts)
 
# plt.show()

# %% [markdown]
# ## Extra practice

# %%
 
qc_extra = QuantumCircuit(3)
qc_extra.h(0)
qc_extra.cx(0, 1)
qc_extra.cx(1,2)
qc_extra.measure_all()
 
sampler = StatevectorSampler()
result = sampler.run([qc_extra], shots=1024).result()
print(result[0].data.meas.get_counts())

from qiskit.visualization import circuit_drawer
circuit_drawer(qc_extra)
# Out:
# {'000': 511, '111': 513}
#         ┌───┐           ░ ┌─┐
#    q_0: ┤ H ├──■────────░─┤M├──────
#         └───┘┌─┴─┐      ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──■───░──╫─┤M├───
#              └───┘┌─┴─┐ ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├─░──╫──╫─┤M├
#                   └───┘ ░  ║  ║ └╥┘
# meas: 3/═══════════════════╩══╩══╩═
#                            0  1  2

# %%
qc_extra_2 = QuantumCircuit(3)
qc_extra_2.h(0)
qc_extra_2.cx(0, 1)
qc_extra_2.cx(1,2)
qc_extra_2.x(1)
qc_extra_2.measure_all()
 
sampler = StatevectorSampler()
result = sampler.run([qc_extra_2], shots=1024).result()
print(result[0].data.meas.get_counts())

from qiskit.visualization import circuit_drawer
circuit_drawer(qc_extra_2)
# Out:
# {'101': 518, '010': 506}
#         ┌───┐                ░ ┌─┐
#    q_0: ┤ H ├──■─────────────░─┤M├──────
#         └───┘┌─┴─┐     ┌───┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├──■──┤ X ├─░──╫─┤M├───
#              └───┘┌─┴─┐└───┘ ░  ║ └╥┘┌─┐
#    q_2: ──────────┤ X ├──────░──╫──╫─┤M├
#                   └───┘      ░  ║  ║ └╥┘
# meas: 3/════════════════════════╩══╩══╩═
#                                 0  1  2
